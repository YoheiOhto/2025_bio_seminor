# %%
import zipfile
import os

zip_path = "/workspace/2-bio_seminor_2025/0-bio_seminor/github/2025_bio_seminor/data/MAPE-PPI/raw_data.zip"
extract_dir = "/workspace/2-bio_seminor_2025/0-bio_seminor/github/2025_bio_seminor/data/MAPE-PPI/raw_data"

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(extract_dir)

# %%
zip_path = "/workspace/2-bio_seminor_2025/0-bio_seminor/github/2025_bio_seminor/data/MAPE-PPI/compressed/processed_data.zip"
extract_dir = "/workspace/2-bio_seminor_2025/0-bio_seminor/github/2025_bio_seminor/data/MAPE-PPI/data"

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(extract_dir)
